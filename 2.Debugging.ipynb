# %%
#1.Find the error in the following Python code:

 for i in range(5)
    print(i)

# %% [markdown]
# ans: missing colon

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?
a = 10
b = "5"
print(a + b)

# %% [markdown]
# ans: value is in string so changed to int values

# %%
a = 10
b = "5"
print(a + int( b))
# Out:
# 15

# %%
#3.What is the issue in this Python snippet?

 def add_numbers(a, b)
    return a + b

# %% [markdown]
# ans: missing colon

# %%
 def add_numbers(a, b):
    return a + b

# %%
#4.Identify the bug in the following Python code:

 numbers = [1, 2, 3, 4]
print(numbers[4])

# %%
numbers = [1, 2, 3, 4]
print(numbers[3])
# Out:
# 4

# %% [markdown]
# ans: index position[0,1,2,3]

# %%
#5.Find the error in the following Python code:
print "Hello, World!"

# %% [markdown]
# ans: in print, must use ()

# %%
print ("Hello, World!")
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
x = 5 / 0

# %% [markdown]
# ans: not divisible by zero

# %%
x = 5 / 1

# %%
#7.Find the error in the following Python code:name = "Alice"
age = 25
print("Name: " + name + ", Age: " + age)

# %% [markdown]
# age is an integer when name is string. (+)operator used here so str(age), if (,) instead of(+) ("Name:", name, ", Age:", age) no need to use str

# %%
age = 25
name="alice"
print("Name: " + name + ", Age: " + str(age))
# Out:
# Name: alice, Age: 25

# %%
#8.Find the error
for i in range(1, 10, -1):
    print(i)

# %%
for i in range(1, 10, -1):
    print(i)

# %% [markdown]
# ans: (start,stop,step)(1, 10, -1)
# moving backward like( 1,0,-1,-2.-3)(for this given range never reach stop value 10 because 1 is already less than 10)

# %%
for i in range(10, 1, -1):
    print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
#9. Find the error in the following Python code:
x = 10
if x = 5:
    print("x is 5")

# %% [markdown]
# ans: = (assign )  == comparing )

# %%
x = 10
if x==5:
    print("x is 5")

# %%
#10. Identify the error in the following function definition:

def greet(name)
    print("Hello, " + name)

# %%
ans: missing colon

# %%
def greet(name):
    print("Hello, " + name)
